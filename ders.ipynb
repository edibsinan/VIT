# %%
websitesi ="http://www.sadikturan.com"

course ="Python Kursu: Baştan Sona Python Programlama Rehberiniz (40 saat)"

result='    Hello World '.strip()
print(result)
result='   Hello World '.lstrip()
print(result)

result='    Hello World '.rstrip()
print(result)

result=websitesi.lstrip('htp:/')
print(result)

result=websitesi.strip('htp:/w.com')
print(result)

course=course.lower()
print(course)

result=websitesi.count('www', 0,10)
print(result,'adet var')

result=websitesi.startswith('http')
print(result)
result=websitesi.endswith('com')
print(result)

result=websitesi.find('com')
print(result)

result=websitesi.index('com')
print(result)

result=course.isalpha()
print(result)

result='hello'.isalpha()
print(result)

result='123'.isdigit()
print(result)

result='contents'.center(50,'*')
print(result)
result='contents'.rjust(50,'*')
print(result)
result='contents'.ljust(50,'*')
print(result)

result=course.replace(' ','-',3)
print(result)

result='hello world'.replace('hello','merhaba')
print(result)

result=course.split()
print(result)

result=result[2]
print(result)
# Out:
# Hello World
# Hello World
#     Hello World
# www.sadikturan.com
# sadikturan
# python kursu: baştan sona python programlama rehberiniz (40 saat)
# 1 adet var
# True
# True
# 22
# 22
# False
# True
# True
# *********************contents*********************
# ******************************************contents
# contents******************************************
# python-kursu:-baştan-sona python programlama rehberiniz (40 saat)
# merhaba world
# ['python', 'kursu:', 'baştan', 'sona', 'python', 'programlama', 'rehberiniz', '(40', 'saat)']
# baştan
